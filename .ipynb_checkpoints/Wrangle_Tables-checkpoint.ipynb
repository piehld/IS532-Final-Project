# %% [markdown]
# # Wrangle Tables into Relational Model
#
# Tables:
#
# - Wars
# - War_Deaths
# - War_LargerConflicts
# - War_Locations
# - Locations
# - Participants
# - War_Participants
# - Participant_ParticipantTypes
# - ParticipantTypes

# %%
import pandas as pd

# %%
war_par = pd.read_csv("Data/Queried/wars_participants.csv")
war = pd.read_csv("Data/Queried/wars.csv")
locs = pd.read_csv("Data/Queried/war_locations.csv")
par = pd.read_csv("Data/Queried/participants.csv")

# %%
war_par['warID'] = war_par['event'].str.split('/').str[-1]
war_par['participantID'] = war_par['participant'].str.split('/').str[-1]

war['warID'] = war['event'].str.split('/').str[-1]
war['locationID'] = war['location'].str.split('/').str[-1]
war['prevWarID'] = war['prevWar'].str.split('/').str[-1]
war['nextWarID'] = war['nextWar'].str.split('/').str[-1]
war['largerConflictID'] = war['largerConflict'].str.split('/').str[-1]

locs['locationID'] = locs['location'].str.split('/').str[-1]

par['participantID'] = par['participant'].str.split('/').str[-1]

# %% [markdown]
# ## Create Wars table
#
# Attributes:
#
# - warID
# - warName
# - startDate
# - endDate
# - warDescription
# - prevWarID
# - nextWarID

# %%
war
# Out:
#                                         event                  eventLabel  \
# 0      http://www.wikidata.org/entity/Q170682                    Gaza War
# 1      http://www.wikidata.org/entity/Q170682                    Gaza War
# 2       http://www.wikidata.org/entity/Q49092     1947–1949 Palestine war
# 3      http://www.wikidata.org/entity/Q179275  War in North-West Pakistan
# 4      http://www.wikidata.org/entity/Q185729               War on Terror
# ..                                        ...                         ...
# 309  http://www.wikidata.org/entity/Q16335075              War in Donbass
# 310  http://www.wikidata.org/entity/Q42410520            First Rwanda War
# 311  http://www.wikidata.org/entity/Q42306428           First Burundi War
# 312   http://www.wikidata.org/entity/Q1773984       Batalla del pan dulce
# 313  http://www.wikidata.org/entity/Q42410655          Second Liberia War
#
#                                       eventDescription             startDate  \
# 0    December 2008-January 2009 armed conflict in t...  2008-12-27T00:00:00Z
# 1    December 2008-January 2009 armed conflict in t...  2008-12-27T00:00:00Z
# 2    Ando cheques no están depende si Israel War Th...  1947-10-30T00:00:00Z
# 3    armed conflict involving Pakistan and armed mi...  2004-03-16T00:00:00Z
# 4    international military campaign that started a...  2001-09-11T00:00:00Z
# ..                                                 ...                   ...
# 309    armed conflict in the Donbass region of Ukraine  2014-04-06T00:00:00Z
# 310         Civil War for Capital between 1963 to 1964  1963-01-01T00:00:00Z
# 311                      Civil War for capital in 1972  1972-01-01T00:00:00Z
# 312                     Batalla entre pacistas y ateos  1950-10-06T00:00:00Z
# 313         Civil War for Capital between 1992 to 1995  1992-01-01T00:00:00Z
#
#                   endDate                                 location  \
# 0    2009-01-18T00:00:00Z    http://www.wikidata.org/entity/Q39760
# 1    2009-01-18T00:00:00Z    http://www.wikidata.org/entity/Q39760
# 2    1949-03-10T00:00:00Z    http://www.wikidata.org/entity/Q36755
# 3                     NaN   http://www.wikidata.org/entity/Q208270
# 4                     NaN                                      NaN
# ..                    ...                                      ...
# 309                   NaN   http://www.wikidata.org/entity/Q171965
# 310  1964-01-01T00:00:00Z     http://www.wikidata.org/entity/Q1037
# 311  1972-01-01T00:00:00Z      http://www.wikidata.org/entity/Q967
# 312  1951-01-01T00:00:00Z  http://www.wikidata.org/entity/Q1012419
# 313  1995-01-01T00:00:00Z     http://www.wikidata.org/entity/Q1014
#
#      casualties prevWar nextWar                            largerConflict  \
# 0           NaN     NaN     NaN    http://www.wikidata.org/entity/Q553184
# 1           NaN     NaN     NaN  http://www.wikidata.org/entity/Q15059994
# 2           NaN     NaN     NaN      http://www.wikidata.org/entity/Q8669
# 3           NaN     NaN     NaN    http://www.wikidata.org/entity/Q185729
# 4           NaN     NaN     NaN                                       NaN
# ..          ...     ...     ...                                       ...
# 309       375.0     NaN     NaN  http://www.wikidata.org/entity/Q16918333
# 310         NaN     NaN     NaN                                       NaN
# 311         NaN     NaN     NaN                                       NaN
# 312         NaN     NaN     NaN  http://www.wikidata.org/entity/Q13557549
# 313         NaN     NaN     NaN                                       NaN
#
#          warID locationID prevWarID nextWarID largerConflictID
# 0      Q170682     Q39760       NaN       NaN          Q553184
# 1      Q170682     Q39760       NaN       NaN        Q15059994
# 2       Q49092     Q36755       NaN       NaN            Q8669
# 3      Q179275    Q208270       NaN       NaN          Q185729
# 4      Q185729        NaN       NaN       NaN              NaN
# ..         ...        ...       ...       ...              ...
# 309  Q16335075    Q171965       NaN       NaN        Q16918333
# 310  Q42410520      Q1037       NaN       NaN              NaN
# 311  Q42306428       Q967       NaN       NaN              NaN
# 312   Q1773984   Q1012419       NaN       NaN        Q13557549
# 313  Q42410655      Q1014       NaN       NaN              NaN
#
# [314 rows x 15 columns]

# %%
war_table = war[['warID', 'eventLabel', 'eventDescription', 'startDate', 'endDate', 'prevWarID', 'nextWarID']].copy().drop_duplicates() \
            .rename(columns={'eventLabel':'warName', 'eventDescription':'warDescription'})

# %%
war_table[war_table.duplicated(subset=['warID'], keep=False)]
# Out:
#         warID                warName                  warDescription  \
# 184   Q877450      Laotian Civil War     1959–1975 civil war in Laos
# 189   Q877450      Laotian Civil War     1959–1975 civil war in Laos
# 230  Q1773984  Batalla del pan dulce  Batalla entre pacistas y ateos
# 265  Q1773984  Batalla del pan dulce  Batalla entre pacistas y ateos
# 270  Q1773984  Batalla del pan dulce  Batalla entre pacistas y ateos
# 312  Q1773984  Batalla del pan dulce  Batalla entre pacistas y ateos
#
#                 startDate               endDate prevWarID nextWarID
# 184  1959-05-23T00:00:00Z  1975-12-02T00:00:00Z       NaN       NaN
# 189  1953-11-09T00:00:00Z  1975-12-02T00:00:00Z       NaN       NaN
# 230  1950-01-01T00:00:00Z  1950-10-19T00:00:00Z       NaN       NaN
# 265  1950-10-06T00:00:00Z  1950-10-19T00:00:00Z       NaN       NaN
# 270  1950-01-01T00:00:00Z  1951-01-01T00:00:00Z       NaN       NaN
# 312  1950-10-06T00:00:00Z  1951-01-01T00:00:00Z       NaN       NaN

# %% [markdown]
# - for Q877450: drop 189 based on Wikipedia entry for war, which specifies start date of 23 May 1959
# - for Q1773984: drop observations with less specificity (230, 270, 312) in favor of observation with most specificity (265)

# %%
war_table = war_table.drop([189, 230, 270, 312])

# %%
war_table.to_csv('Data/Wrangled/war.csv', index=False)

# %% [markdown]
# ## Create the War tables for multivalued attributes
#
# - War_Deaths
# - War_LargerConflicts
# - War_Locations

# %%
war_deaths = war[['warID', 'casualties']].copy().drop_duplicates().dropna().rename(columns={'casualties':'deaths'})
war_deaths['deaths'] = war_deaths['deaths'].astype(int)
war_deaths.to_csv('Data/Wrangled/war_deaths.csv', index=False)

# %%
war_locations = war[['warID', 'locationID']].copy().drop_duplicates().dropna()
war_locations.to_csv('Data/Wrangled/war_locations.csv', index=False)

# %%
war_largerconflict = war[['warID', 'largerConflictID']].copy().drop_duplicates().dropna()
war_largerconflict.to_csv('Data/Wrangled/war_largerconflicts.csv', index=False)

# %% [markdown]
# ### Houston, we have a problem

# %%
conflictIDs = set(war['largerConflictID'].dropna().unique())
warIDs = set(war['warID'].dropna().unique())
not_wars = conflictIDs - warIDs
len(conflictIDs), len(not_wars)
# Out:
# (75, 41)

# %% [markdown]
# Out of 75 larger conflicts, 41 are not wars, and thus will not be present in the wars table, so there cannot be a foreign key to the wars table as is.

# %%
pwIDs = set(war['prevWarID'].dropna().unique())
warIDs = set(war['warID'].dropna().unique())
not_wars_pw = pwIDs - warIDs
len(pwIDs), len(not_wars_pw)
# Out:
# (8, 3)

# %%
nwIDs = set(war['nextWarID'].dropna().unique())
warIDs = set(war['warID'].dropna().unique())
not_wars_nw = nwIDs - warIDs
len(nwIDs), len(not_wars_nw)
# Out:
# (7, 2)

# %%
not_wars_pw, not_wars_nw
# Out:
# ({'Q2405009', 'Q2629782', 'Q2992527'}, {'Q2405009', 'Q3446062'})

# %% [markdown]
# There's also a problem with some of the "next wars" and "previous wars" - 4 of them aren't in the original war list.
#
# - Q2405009 lacks an "instance of" attribute
# - Q2629782 and Q2992527 happen before 1945
# - Q3446062 is an instance of conflict, not of war

# %% [markdown]
# ## Create Locations table
#
# - locationID
# - locationName
# - locationType
# - coordinates

# %%
locs
# Out:
#                                     location         locationLabel  \
# 0     http://www.wikidata.org/entity/Q231151      Tindouf Province
# 1    http://www.wikidata.org/entity/Q1480109      Southern Lebanon
# 2       http://www.wikidata.org/entity/Q5118  Republic of Dagestan
# 3        http://www.wikidata.org/entity/Q889           Afghanistan
# 4        http://www.wikidata.org/entity/Q792           El Salvador
# ..                                       ...                   ...
# 161     http://www.wikidata.org/entity/Q1008           Ivory Coast
# 162   http://www.wikidata.org/entity/Q217169              Rhodesia
# 163      http://www.wikidata.org/entity/Q739              Colombia
# 164      http://www.wikidata.org/entity/Q810                Jordan
# 165   http://www.wikidata.org/entity/Q171965        Luhansk Oblast
#
#                                    locationDescription  \
# 0                                  province of Algeria
# 1                                    geographic region
# 2        federal subject of Russia, republic of Russia
# 3    sovereign state situated at the confluence of ...
# 4                   sovereign state in Central America
# ..                                                 ...
# 161                          sovereign state in Africa
# 162                           former country in Africa
# 163                   sovereign state in South America
# 164                    sovereign state in Western Asia
# 165                                  oblast in Ukraine
#
#                           coordinates locationID
# 0    Point(-8.133333333 27.683333333)    Q231151
# 1                                 NaN   Q1480109
# 2            Point(46.883333333 43.1)      Q5118
# 3                    Point(66.0 34.0)       Q889
# 4         Point(-88.866111 13.668889)       Q792
# ..                                ...        ...
# 161                   Point(-6.0 8.0)      Q1008
# 162        Point(31.029722 17.863889)    Q217169
# 163                  Point(-74.0 4.0)       Q739
# 164                  Point(36.5 31.2)       Q810
# 165                Point(39.02 48.92)    Q171965
#
# [166 rows x 5 columns]

# %%
locations = locs[['locationID', 'locationLabel', 'locationDescription', 'coordinates']].copy().drop_duplicates()

# %%
locations[locations.duplicated(subset=['locationID'], keep=False)].sort_values(by='locationID')
# Out:
#     locationID             locationLabel  \
# 94    Q1288434     Condorcanqui Province
# 78    Q1288434     Condorcanqui Province
# 135   Q1948210           Catatumbo River
# 121   Q1948210           Catatumbo River
# 18    Q1993836       Ecuador–Peru border
# 103   Q1993836       Ecuador–Peru border
# 57    Q2399139   Bangladesh–India border
# 91    Q2399139   Bangladesh–India border
# 16    Q3088996       Syria–Turkey border
# 19    Q3088996       Syria–Turkey border
# 96    Q3089020  Burkina Faso–Mali border
# 100   Q3089020  Burkina Faso–Mali border
# 148    Q882739                 Blue Nile
# 138    Q882739                 Blue Nile
# 119    Q882739                 Blue Nile
# 49        Q899                Suez Canal
# 14        Q899                Suez Canal
#
#                                    locationDescription  \
# 94                          province of Amazonas, Peru
# 78                          province of Amazonas, Peru
# 135                                 river in Venezuela
# 121                                 river in Venezuela
# 18         divides the territories of Ecuador and Peru
# 103        divides the territories of Ecuador and Peru
# 57   Separates territories of Bangladesh and India ...
# 91   Separates territories of Bangladesh and India ...
# 16                                international border
# 19                                international border
# 96                                international border
# 100                               international border
# 148    river in Africa and tributary of the Nile River
# 138    river in Africa and tributary of the Nile River
# 119    river in Africa and tributary of the Nile River
# 49   canal in Egypt between the Mediterranean and R...
# 14   canal in Egypt between the Mediterranean and R...
#
#                           coordinates
# 94          Point(-77.9 -4.583055555)
# 78           Point(-78.0384 -4.16515)
# 135  Point(-71.710555555 9.344166666)
# 121       Point(-71.7106 9.344169444)
# 18        Point(-81.153481 -3.392125)
# 103       Point(-75.257994 -0.118174)
# 57   Point(92.608328703 21.976388888)
# 91         Point(89.708888888 18.565)
# 16   Point(35.159166666 36.014444444)
# 19   Point(42.363888888 37.111106481)
# 96   Point(-5.519444444 10.434717592)
# 100   Point(0.230555555 14.988888888)
# 148  Point(32.501944444 15.623611111)
# 138                 Point(37.25 12.0)
# 119             Point(37.408 11.6206)
# 49         Point(32.344166666 30.705)
# 14   Point(32.562777777 29.931388888)

# %%
locations = locations.drop([78, 135, 19, 138, 148, 14])

# %%
locations.to_csv('Data/Wrangled/locations.csv', index=False)

# %% [markdown]
# ## Create War_Participants table
#
# - warID
# - participantID

# %%
war_participants = war_par[['warID', 'participantID']].copy().drop_duplicates().dropna()
war_participants.to_csv('Data/Wrangled/war_participants.csv', index=False)

# %% [markdown]
# ## Create Participants table
#
# - participantID
# - participantLabel
# - participantDescription
# - type
# - inception
# - dissolved
# - countryCode

# %%
participants = par[['participantID', 'participantLabel', 'participantDescription', 'type', 'inception', 'dissolved', 'countryCode']].copy()

# %%
participants[participants.duplicated(subset=['participantID'], keep=False)].sort_values(by='participantID')
# Out:
#     participantID                      participantLabel  \
# 166       Q146885                Second Syrian Republic
# 168       Q146885                Second Syrian Republic
# 197       Q146885                Second Syrian Republic
# 200       Q146885                Second Syrian Republic
# 370           Q20                                Norway
# 369           Q20                                Norway
# 366           Q20                                Norway
# 357           Q20                                Norway
# 280      Q2429253  Islamic State of Iraq and the Levant
# 276      Q2429253  Islamic State of Iraq and the Levant
# 398          Q736                               Ecuador
# 383          Q736                               Ecuador
# 401          Q736                               Ecuador
# 300           Q79                                 Egypt
# 299           Q79                                 Egypt
# 399          Q869                              Thailand
# 505          Q869                              Thailand
# 371          Q881                               Vietnam
# 325          Q881                               Vietnam
# 362          Q889                           Afghanistan
# 354          Q889                           Afghanistan
# 375          Q889                           Afghanistan
# 376          Q889                           Afghanistan
# 342          Q889                           Afghanistan
# 341          Q889                           Afghanistan
# 332          Q889                           Afghanistan
# 364          Q889                           Afghanistan
#
#                                 participantDescription   type  \
# 166  government of Syria from 1950 to 1958 and 1961...  State
# 168  government of Syria from 1950 to 1958 and 1961...  State
# 197  government of Syria from 1950 to 1958 and 1961...  State
# 200  government of Syria from 1950 to 1958 and 1961...  State
# 370                 sovereign state in Northern Europe  State
# 369                 sovereign state in Northern Europe  State
# 366                 sovereign state in Northern Europe  State
# 357                 sovereign state in Northern Europe  State
# 280       Salafi jihadist terrorist and militant group  State
# 276       Salafi jihadist terrorist and militant group  State
# 398                   sovereign state in South America  State
# 383                   sovereign state in South America  State
# 401                   sovereign state in South America  State
# 300                 sovereign state in Africa and Asia  State
# 299                 sovereign state in Africa and Asia  State
# 399                  sovereign state in Southeast Asia  State
# 505                  sovereign state in Southeast Asia  State
# 371                  sovereign state in Southeast Asia  State
# 325                  sovereign state in Southeast Asia  State
# 362  sovereign state situated at the confluence of ...  State
# 354  sovereign state situated at the confluence of ...  State
# 375  sovereign state situated at the confluence of ...  State
# 376  sovereign state situated at the confluence of ...  State
# 342  sovereign state situated at the confluence of ...  State
# 341  sovereign state situated at the confluence of ...  State
# 332  sovereign state situated at the confluence of ...  State
# 364  sovereign state situated at the confluence of ...  State
#
#                  inception             dissolved countryCode
# 166   1950-01-01T00:00:00Z  1963-01-01T00:00:00Z         NaN
# 168   1950-01-01T00:00:00Z  1958-01-01T00:00:00Z         NaN
# 197   1961-01-01T00:00:00Z  1963-01-01T00:00:00Z         NaN
# 200   1961-01-01T00:00:00Z  1958-01-01T00:00:00Z         NaN
# 370   0900-01-01T00:00:00Z                   NaN         NOR
# 369   1905-06-07T00:00:00Z                   NaN         NOR
# 366   1905-10-26T00:00:00Z                   NaN         NOR
# 357   1814-05-17T00:00:00Z                   NaN         NOR
# 280   2006-01-01T00:00:00Z                   NaN         NaN
# 276   1999-01-01T00:00:00Z                   NaN         NaN
# 398   1809-08-10T00:00:00Z                   NaN         ECU
# 383   1811-10-11T00:00:00Z                   NaN         ECU
# 401   1822-05-24T00:00:00Z                   NaN         ECU
# 300  -3149-01-01T00:00:00Z                   NaN         EGY
# 299   1922-02-28T00:00:00Z                   NaN         EGY
# 399   1238-01-01T00:00:00Z                   NaN         THA
# 505   1768-12-28T00:00:00Z                   NaN         THA
# 371   1976-07-02T00:00:00Z                   NaN         VNM
# 325   1945-09-02T00:00:00Z                   NaN         VNM
# 362   1709-01-01T00:00:00Z                   NaN         AFG
# 354   2002-01-01T00:00:00Z                   NaN         AFG
# 375   1973-01-01T00:00:00Z                   NaN         AFG
# 376   1747-06-19T00:00:00Z                   NaN         AFG
# 342   1926-01-01T00:00:00Z                   NaN         AFG
# 341   1992-01-01T00:00:00Z                   NaN         AFG
# 332   1978-01-01T00:00:00Z                   NaN         AFG
# 364   1823-01-01T00:00:00Z                   NaN         AFG

# %%
participants = participants.drop([])

# %%
participants.to_csv('Data/Wrangled/participants.csv', index=False)
